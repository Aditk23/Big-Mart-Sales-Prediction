# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
train['train_test']=0
test['train_test']=1
test['Item_Outlet_Sales'] = np.NaN
all_data = pd.concat([train,test])
all_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat         0.016047
# 1              DRC01         5.92          Regular         0.019278
# 2              FDN15        17.50          Low Fat         0.016760
# 3              FDX07        19.20          Regular         0.000000
# 4              NCD19         8.93          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 5676           FDB58        10.50          Regular         0.013496
# 5677           FDD47         7.60          Regular         0.142991
# 5678           NCO17        10.00          Low Fat         0.073529
# 5679           FDJ26        15.30          Regular         0.000000
# 5680           FDU37         9.50          Regular         0.104720
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
all_data = all_data.reset_index(drop=True)

# %%
all_data.loc[all_data.Item_Identifier=='FDA15'].Item_Weight
# Out:
# 0       9.3
# 831     9.3
# 2599    9.3
# 2643    9.3
# 4874    9.3
# 5413    9.3
# 6696    NaN
# 7543    9.3
# 9638    9.3
# Name: Item_Weight, dtype: float64

# %%
missing = all_data.loc[pd.isnull(all_data.Item_Weight)].index
for i in missing:
    ii = all_data.iloc[i].Item_Identifier
    value = all_data.loc[all_data.Item_Identifier==ii].Item_Weight.mean()
    all_data.loc[all_data.index==i,'Item_Weight'] = value

# %%
sns.distplot(all_data.Item_Visibility)
# Out:
# /Users/apple/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %%
all_data.loc[all_data.Item_Visibility==0].Item_Identifier.value_counts()
# Out:
# FDY07    6
# FDO10    4
# NCK54    4
# NCP05    3
# NCK29    3
#         ..
# NCU17    1
# FDA21    1
# NCA05    1
# DRF60    1
# FDS14    1
# Name: Item_Identifier, Length: 683, dtype: int64

# %%
missing = all_data.loc[all_data.Item_Visibility==0].index
for i in missing:
    ii = all_data.iloc[i].Item_Identifier
    value = all_data.loc[all_data.Item_Identifier==ii].Item_Visibility.mean()
    all_data.loc[all_data.index==i,'Item_Visibility'] = value

# %%
sns.histplot(all_data.Item_Visibility)
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Count'>

# %%
all_data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# train_test                      0
# dtype: int64

# %%
all_data.Outlet_Identifier.value_counts()
# Out:
# OUT027    1559
# OUT013    1553
# OUT049    1550
# OUT046    1550
# OUT035    1550
# OUT045    1548
# OUT018    1546
# OUT017    1543
# OUT010     925
# OUT019     880
# Name: Outlet_Identifier, dtype: int64

# %%
m = all_data[pd.isnull(all_data.Outlet_Size)]

# %%
m.Outlet_Identifier.value_counts()
# Out:
# OUT045    1548
# OUT017    1543
# OUT010     925
# Name: Outlet_Identifier, dtype: int64

# %%
chart = sns.countplot(x="Outlet_Type", hue="Outlet_Size", data=all_data)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Supermarket Type1'),
#  Text(1, 0, 'Supermarket Type2'),
#  Text(2, 0, 'Grocery Store'),
#  Text(3, 0, 'Supermarket Type3')]

# %%
all_data.loc[pd.isnull(all_data.Outlet_Size)&(all_data.Outlet_Type=='Supermarket Type2'),'Outlet_Size']='Medium'
all_data.loc[pd.isnull(all_data.Outlet_Size)&(all_data.Outlet_Type=='Grocery Store'),'Outlet_Size']='Small'
all_data.loc[pd.isnull(all_data.Outlet_Size)&(all_data.Outlet_Type=='Supermarket Type3'),'Outlet_Size']='Medium'

# %%
all_data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  3091
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# train_test                      0
# dtype: int64

# %%
m = all_data[pd.isnull(all_data.Outlet_Size)]
m
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8               FDH17       16.200          Regular         0.016687
# 9               FDU28       19.200          Regular         0.094450
# 25              NCD06       13.000          Low Fat         0.099887
# 33              FDO23       17.850          Low Fat         0.142462
# 46              NCP05       19.600          Low Fat         0.018757
# ...               ...          ...              ...              ...
# 14185           FDK22        9.800          Low Fat         0.026234
# 14193           FDO03       10.395          Regular         0.037092
# 14201           NCO17       10.000          Low Fat         0.073529
# 14202           FDJ26       15.300          Regular         0.088380
# 14203           FDU37        9.500          Regular         0.104720
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 8            Frozen Foods   96.9726            OUT045
# ...

# %%
chart = sns.countplot(x="Outlet_Location_Type", hue="Outlet_Size", data=all_data)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Tier 1'), Text(1, 0, 'Tier 3'), Text(2, 0, 'Tier 2')]

# %%
all_data.loc[pd.isnull(all_data.Outlet_Size)&(all_data.Outlet_Location_Type=='Tier 2'),'Outlet_Size']='Small'

# %%
all_data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# train_test                      0
# dtype: int64

# %%
all_data.Item_Identifier.value_counts()
# Out:
# FDP10    10
# FDL14    10
# NCG18    10
# FDX26    10
# FDR15    10
#          ..
# FDM50     7
# FDL50     7
# FDI46     7
# FDO33     7
# NCW54     7
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
all_data.loc[all_data.Item_Identifier.str.startswith('FD'),'Item_Category'] = 'Food'
all_data.loc[all_data.Item_Identifier.str.startswith('DR'),'Item_Category'] = 'Drink'
all_data.loc[all_data.Item_Identifier.str.startswith('NC'),'Item_Category'] = 'Non Consumable'

# %%
all_data.Item_Category.value_counts()
# Out:
# Food              10201
# Non Consumable     2686
# Drink              1317
# Name: Item_Category, dtype: int64

# %%
all_data = all_data.drop(['Item_Identifier'],1)

# %%
all_data.loc[all_data.Item_Category == 'Non Consumable','Item_Fat_Content'] = 'Not Edible'

# %%
all_data
# Out:
#        Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0             9.30          Low Fat         0.016047                  Dairy
# 1             5.92          Regular         0.019278            Soft Drinks
# 2            17.50          Low Fat         0.016760                   Meat
# 3            19.20          Regular         0.017834  Fruits and Vegetables
# 4             8.93       Not Edible         0.009780              Household
# ...            ...              ...              ...                    ...
# 14199        10.50          Regular         0.013496            Snack Foods
# 14200         7.60          Regular         0.142991          Starchy Foods
# 14201        10.00       Not Edible         0.073529     Health and Hygiene
# 14202        15.30          Regular         0.088380                 Canned
# 14203         9.50          Regular         0.104720                 Canned
#
# ...

# %%
all_data.Item_Fat_Content.value_counts()
# Out:
# Low Fat       5998
# Regular       4824
# Not Edible    2686
# LF             367
# reg            195
# low fat        134
# Name: Item_Fat_Content, dtype: int64

# %%
all_data.Item_Fat_Content = all_data.Item_Fat_Content.replace({'reg':'Regular','LF':'Low Fat','low fat':'Low Fat'})

# %%
all_data['Age'] = 2020 - all_data['Outlet_Establishment_Year']

# %%
all_data['MRP_per_weight'] = all_data['Item_MRP']/all_data['Item_Weight']

# %%
all_data.loc[all_data.Item_MRP <=70 ,'MRP_cluster'] = 1
all_data.loc[(all_data.Item_MRP >70) & (all_data.Item_MRP <=140) ,'MRP_cluster'] = 2
all_data.loc[(all_data.Item_MRP >140) & (all_data.Item_MRP <=200) ,'MRP_cluster'] = 3
all_data.loc[all_data.Item_MRP >200 ,'MRP_cluster'] = 4

# %%
all_data
# Out:
#        Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0             9.30          Low Fat         0.016047                  Dairy
# 1             5.92          Regular         0.019278            Soft Drinks
# 2            17.50          Low Fat         0.016760                   Meat
# 3            19.20          Regular         0.017834  Fruits and Vegetables
# 4             8.93       Not Edible         0.009780              Household
# ...            ...              ...              ...                    ...
# 14199        10.50          Regular         0.013496            Snack Foods
# 14200         7.60          Regular         0.142991          Starchy Foods
# 14201        10.00       Not Edible         0.073529     Health and Hygiene
# 14202        15.30          Regular         0.088380                 Canned
# 14203         9.50          Regular         0.104720                 Canned
#
# ...

# %%
all_data.Outlet_Location_Type.unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
all_data.Outlet_Size = all_data.Outlet_Size.map({'Small':0,'Medium':1,'High':2})
all_data.Outlet_Location_Type = all_data.Outlet_Location_Type.map({'Tier 1':0,'Tier 2':1,'Tier 3':2})

# %%
all_data
# Out:
#        Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0             9.30          Low Fat         0.016047                  Dairy
# 1             5.92          Regular         0.019278            Soft Drinks
# 2            17.50          Low Fat         0.016760                   Meat
# 3            19.20          Regular         0.017834  Fruits and Vegetables
# 4             8.93       Not Edible         0.009780              Household
# ...            ...              ...              ...                    ...
# 14199        10.50          Regular         0.013496            Snack Foods
# 14200         7.60          Regular         0.142991          Starchy Foods
# 14201        10.00       Not Edible         0.073529     Health and Hygiene
# 14202        15.30          Regular         0.088380                 Canned
# 14203         9.50          Regular         0.104720                 Canned
#
# ...

# %%
all_data = all_data.copy()

# %%
all_data = pd.get_dummies(all_data)

# %%
all_data
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0             9.30         0.016047  249.8092                       1999
# 1             5.92         0.019278   48.2692                       2009
# 2            17.50         0.016760  141.6180                       1999
# 3            19.20         0.017834  182.0950                       1998
# 4             8.93         0.009780   53.8614                       1987
# ...            ...              ...       ...                        ...
# 14199        10.50         0.013496  141.3154                       1997
# 14200         7.60         0.142991  169.1448                       2009
# 14201        10.00         0.073529  118.7440                       2002
# 14202        15.30         0.088380  214.6218                       2007
# 14203         9.50         0.104720   79.7960                       2002
#
#        Outlet_Size  Outlet_Location_Type  Item_Outlet_Sales  train_test  Age  \
# ...

# %%
sns.distplot(all_data.Item_Visibility)
# Out:
# /Users/apple/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %%
sns.distplot(all_data.MRP_per_weight)
# Out:
# /Users/apple/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MRP_per_weight', ylabel='Density'>

# %%
all_data.Item_Visibility = np.log(all_data.Item_Visibility+1)
all_data.MRP_per_weight = np.log(all_data.MRP_per_weight+1)

# %%
all_data.columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Item_Outlet_Sales', 'train_test', 'Age', 'MRP_per_weight',
#        'MRP_cluster', 'Item_Fat_Content_Low Fat',
#        'Item_Fat_Content_Not Edible', 'Item_Fat_Content_Regular',
#        'Item_Type_Baking Goods', 'Item_Type_Breads', 'Item_Type_Breakfast',
#        'Item_Type_Canned', 'Item_Type_Dairy', 'Item_Type_Frozen Foods',
#        'Item_Type_Fruits and Vegetables', 'Item_Type_Hard Drinks',
#        'Item_Type_Health and Hygiene', 'Item_Type_Household', 'Item_Type_Meat',
#        'Item_Type_Others', 'Item_Type_Seafood', 'Item_Type_Snack Foods',
#        'Item_Type_Soft Drinks', 'Item_Type_Starchy Foods',
#        'Outlet_Identifier_OUT010', 'Outlet_Identifier_OUT013',
#        'Outlet_Identifier_OUT017', 'Outlet_Identifier_OUT018',
#        'Outlet_Identifier_OUT019', 'Outlet_Identifier_OUT027',
# ...

# %%
all_data = all_data.drop(['Item_Weight','Item_MRP','Outlet_Establishment_Year'],1)

# %%
all_data
# Out:
#        Item_Visibility  Outlet_Size  Outlet_Location_Type  Item_Outlet_Sales  \
# 0             0.015920            1                     0          3735.1380
# 1             0.019095            1                     2           443.4228
# 2             0.016621            1                     0          2097.2700
# 3             0.017677            0                     2           732.3800
# 4             0.009732            2                     2           994.7052
# ...                ...          ...                   ...                ...
# 14199         0.013406            0                     0                NaN
# 14200         0.133648            1                     2                NaN
# 14201         0.070951            0                     1                NaN
# 14202         0.084690            0                     1                NaN
# 14203         0.099592            0                     1                NaN
#
# ...

# %%
train_cleaned = all_data.loc[all_data.train_test==0].drop(['train_test'],1)
test_cleaned = all_data.loc[all_data.train_test==1].drop(['train_test','Item_Outlet_Sales'],1)

# %%
train_cleaned
# Out:
#       Item_Visibility  Outlet_Size  Outlet_Location_Type  Item_Outlet_Sales  \
# 0            0.015920            1                     0          3735.1380
# 1            0.019095            1                     2           443.4228
# 2            0.016621            1                     0          2097.2700
# 3            0.017677            0                     2           732.3800
# 4            0.009732            2                     2           994.7052
# ...               ...          ...                   ...                ...
# 8518         0.055230            2                     2          2778.3834
# 8519         0.045912            0                     1           549.2850
# 8520         0.034581            0                     1          1193.1136
# 8521         0.135597            1                     2          1845.5976
# 8522         0.043900            0                     0           765.6700
#
# ...

# %%
test_cleaned
# Out:
#        Item_Visibility  Outlet_Size  Outlet_Location_Type  Age  \
# 8523          0.007536            1                     0   21
# 8524          0.037708            0                     1   13
# 8525          0.094924            0                     2   22
# 8526          0.015271            0                     1   13
# 8527          0.112077            1                     2   35
# ...                ...          ...                   ...  ...
# 14199         0.013406            0                     0   23
# 14200         0.133648            1                     2   11
# 14201         0.070951            0                     1   18
# 14202         0.084690            0                     1   13
# 14203         0.099592            0                     1   18
#
#        MRP_per_weight  MRP_cluster  Item_Fat_Content_Low Fat  \
# 8523         1.824255          2.0                         1
# 8524         2.444124          2.0                         0
# ...

# %%
train_cleaned.to_csv('train_cleaned.csv',index=False)
test_cleaned.to_csv('test_cleaned.csv',index=False)
